# %% [markdown]
# ## Basline machine Learning for Emotion Detection

# %%
# dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from imblearn.pipeline import Pipeline
from sklearn.model_selection import GroupKFold, cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler


from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

# %%
# data
#df = pd.read_csv(r'..\Data\German\features_german.csv')
#df = pd.read_csv(r'..\Data\Urdu\features_urdu.csv')
df = pd.read_csv(r'..\Data\English\features_english.csv')
df
# Out:
#                         filename   emotion  speaker_id  valence  \
# 0     ..\Data\English\DC\a01.wav     anger           1        0
# 1     ..\Data\English\DC\a02.wav     anger           1        0
# 2     ..\Data\English\DC\a03.wav     anger           1        0
# 3     ..\Data\English\DC\a04.wav     anger           1        0
# 4     ..\Data\English\DC\a05.wav     anger           1        0
# ..                           ...       ...         ...      ...
# 475  ..\Data\English\KL\su11.wav  surprise           4        1
# 476  ..\Data\English\KL\su12.wav  surprise           4        1
# 477  ..\Data\English\KL\su13.wav  surprise           4        1
# 478  ..\Data\English\KL\su14.wav  surprise           4        1
# 479  ..\Data\English\KL\su15.wav  surprise           4        1
#
#      F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                            32.288380
# 1                            28.624495
# 2                            32.756123
# 3                            30.764030
# 4                            32.762295
# ..                                 ...
# 475                          27.108358
# 476                          29.356766
# 477                          29.011467
# 478                          28.444344
# 479                          28.733868
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.253543
# 1                                  0.083322
# 2                                  0.073900
# 3                                  0.126925
# 4                                  0.264996
# ..                                      ...
# 475                                0.206385
# 476                                0.251457
# 477                                0.158787
# 478                                0.174112
# 479                                0.171200
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                     28.019905
# 1                                     27.068924
# 2                                     30.584631
# 3                                     28.082650
# 4                                     28.170233
# ..                                          ...
# 475                                   20.513933
# 476                                   24.306232
# 477                                   25.771938
# 478                                   24.197416
# 479                                   25.216960
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                     31.009491
# 1                                     28.368698
# 2                                     33.153530
# 3                                     31.094275
# 4                                     30.551094
# ..                                          ...
# 475                                   27.355312
# 476                                   27.609499
# 477                                   29.877594
# 478                                   28.833923
# 479                                   29.166946
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                     34.035744
# 1                                     29.564380
# 2                                     34.469784
# 3                                     33.430504
# 4                                     34.771942
# ..                                          ...
# 475                                   32.252160
# 476                                   33.923824
# 477                                   32.168110
# 478                                   32.693607
# 479                                   32.431200
#
#      F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  ...  slopeUV0-500_sma3nz_amean  \
# 0                                    6.015839  ...                  -0.130033
# 1                                    2.495457  ...                  -0.127977
# 2                                    3.885153  ...                  -0.128269
# 3                                    5.347855  ...                  -0.113702
# 4                                    6.601709  ...                  -0.104462
# ..                                        ...  ...                        ...
# 475                                 11.738226  ...                  -0.103756
# 476                                  9.617592  ...                  -0.091886
# 477                                  6.396172  ...                  -0.079930
# 478                                  8.496191  ...                  -0.077113
# 479                                  7.214237  ...                  -0.069713
#
#      slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 0                       -0.008058                     0.175102
# 1                       -0.008800                     0.123429
# 2                       -0.007824                     0.087312
# 3                       -0.010014                     0.088040
# 4                       -0.010390                     0.082960
# ..                            ...                          ...
# 475                     -0.006573                     0.020492
# 476                     -0.008118                     0.022205
# 477                     -0.007662                     0.010094
# 478                     -0.007587                     0.016008
# 479                     -0.012708                     0.019338
#
#      loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0               3.581267              2.234637                    0.296250
# 1               3.508772              0.890208                    0.666667
# 2               2.427185              0.995025                    0.495000
# 3               3.690037              1.127820                    0.553333
# 4               3.691275              1.706485                    0.374000
# ..                   ...                   ...                         ...
# 475             3.500000              2.051282                    0.255000
# 476             4.370180              2.088773                    0.361250
# 477             2.840909              1.734104                    0.366667
# 478             3.238095              2.115385                    0.270909
# 479             4.109589              2.782609                    0.208750
#
#      StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                        0.255389                   0.247500
# 1                        0.507631                   0.325000
# 2                        0.265000                   0.323333
# 3                        0.402851                   0.232500
# 4                        0.653226                   0.188000
# ..                            ...                        ...
# 475                      0.085000                   0.168000
# 476                      0.288593                   0.123333
# 477                      0.174992                   0.161429
# 478                      0.163120                   0.165833
# 479                      0.161357                   0.130625
#
#      StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# 0                       0.217529                -15.691360
# 1                       0.268375                -15.941064
# 2                       0.197540                -13.958084
# 3                       0.181435                -13.020000
# 4                       0.185515                -13.182361
# ..                           ...                       ...
# 475                     0.148513                -38.530186
# 476                     0.129957                -38.795590
# 477                     0.146719                -37.637800
# 478                     0.160803                -37.570038
# 479                     0.147117                -37.724350
#
# [480 rows x 92 columns]

# %%
df["speaker_id"].unique()
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# ### Data Preprocessing
# * we have a small dataset with unbalanced data. we need to be careful about overfitting. We want to have balanced data, so we use SMOTE to oversample the minority class (this usually works well for smaller datasets)
# * we need GroupKfold crossvalidation, as we do not want to have speakers from the training in the test dataset
#
# => we do this all together in the pipepline

# %%
# check classes
df['valence'].value_counts()
# Out:
# valence
# 0    240
# 1    240
# Name: count, dtype: int64

# %% [markdown]
# ### Model Training

# %%
X = df.drop(["emotion", "speaker_id", "filename", "valence"], axis=1)  # Features
y = df["valence"]  # Labels
groups = df["speaker_id"]  

# Initialize GroupKFold with 5 folds 
#gkf = GroupKFold(n_splits=5)

# For the English dataset we initialize with 4 folds (since n = 4 < 5)
gkf = GroupKFold(n_splits=4)

# Initialize models
svm_model = SVC(probability=True, random_state=42)
logreg_model = LogisticRegression(max_iter=1000, random_state=42)
xgb_model = XGBClassifier(random_state=42)
randomForest_model = RandomForestClassifier(random_state=42)

# Create pipelines
svm_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("smote", SMOTE(random_state=42)),
    ("classifier", svm_model)
])

logreg_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("smote", SMOTE(random_state=42)),
    ("classifier", logreg_model)
])

xgb_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("smote", SMOTE(random_state=42)),
    ("classifier", xgb_model)
])

randomForest_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("smote", SMOTE(random_state=42)),
    ("classifier", randomForest_model)
])

# %% [markdown]
# ### Evaluation
# in the paper they used unweighted average recall rate (UAR) which gives equal weight to each class, making it good for imbalanced datasets. UAR is the same as balanced accuracy.
# we choose to check also other metrics, which are good for imbalanced date, like f1 score.

# %%
scoring_metrics = ["accuracy", "balanced_accuracy", "f1_weighted", "roc_auc_ovr", "precision_weighted", "recall_weighted"]
results = []

# Evaluate pipelines using different metrics
for metric in scoring_metrics:
    svm_scores = cross_val_score(svm_pipeline, X, y, groups=groups, cv=gkf, scoring=metric)
    logreg_scores = cross_val_score(logreg_pipeline, X, y, groups=groups, cv=gkf, scoring=metric)
    xgb_scores = cross_val_score(xgb_pipeline, X, y, groups=groups, cv=gkf, scoring=metric)
    randomForest_scores = cross_val_score(randomForest_pipeline, X, y, groups=groups, cv=gkf, scoring=metric)
    
    # Store results
    results.append(["SVM", metric, svm_scores.mean()])
    results.append(["Logistic Regression", metric, logreg_scores.mean()])
    results.append(["Random Forest", metric, randomForest_scores.mean()])
    results.append(["XGBoost", metric, xgb_scores.mean()])


results_df = pd.DataFrame(results, columns=["Model", "Metric", "Score"])
results_df
# Out:
# C:\Users\david\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                   Model              Metric     Score
# 0                   SVM            accuracy  0.589583
# 1   Logistic Regression            accuracy  0.597917
# 2         Random Forest            accuracy  0.570833
# 3               XGBoost            accuracy  0.550000
# 4                   SVM   balanced_accuracy  0.589583
# 5   Logistic Regression   balanced_accuracy  0.597917
# 6         Random Forest   balanced_accuracy  0.570833
# 7               XGBoost   balanced_accuracy  0.550000
# 8                   SVM         f1_weighted  0.548698
# 9   Logistic Regression         f1_weighted  0.553612
# 10        Random Forest         f1_weighted  0.555669
# 11              XGBoost         f1_weighted  0.542978
# 12                  SVM         roc_auc_ovr  0.690382
# 13  Logistic Regression         roc_auc_ovr  0.679028
# 14        Random Forest         roc_auc_ovr  0.596944
# 15              XGBoost         roc_auc_ovr  0.596667
# 16                  SVM  precision_weighted  0.621613
# 17  Logistic Regression  precision_weighted  0.538541
# 18        Random Forest  precision_weighted  0.591495
# 19              XGBoost  precision_weighted  0.561275
# 20                  SVM     recall_weighted  0.589583
# 21  Logistic Regression     recall_weighted  0.597917
# 22        Random Forest     recall_weighted  0.570833
# 23              XGBoost     recall_weighted  0.550000

# %%
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")
sns.set_palette("viridis")
sns.barplot(data=results_df, x="Metric", y="Score", hue="Model")

# Add labels and title
plt.title('Model Performance on Different Metrics', fontsize=16)
plt.xlabel('Model', fontsize=12)
plt.ylabel('Score', fontsize=12)

plt.legend(title="Metric", bbox_to_anchor=(1.05, 0.5), loc='center left')
# Display the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
