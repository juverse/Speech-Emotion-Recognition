# %% [markdown]
# ## Basline machine Learning for Emotion Detection

# %%
# dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from imblearn.pipeline import Pipeline
from sklearn.model_selection import GroupKFold, cross_val_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler


from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

# %%
# data
#df = pd.read_csv(r'..\Data\German\features_german.csv')
#df = pd.read_csv(r'..\Data\Urdu\features_urdu.csv')
#df = pd.read_csv(r'..\Data\English\features_english.csv')
df = pd.read_csv(r'..\Data\Italian\features_italian.csv')
df
# Out:
#                              filename  emotion  speaker_id  valence  \
# 0    ..\Data\Italian\f1\dis-f1-b1.wav  disgust           1        0
# 1    ..\Data\Italian\f1\dis-f1-b2.wav  disgust           1        0
# 2    ..\Data\Italian\f1\dis-f1-b3.wav  disgust           1        0
# 3    ..\Data\Italian\f1\dis-f1-d1.wav  disgust           1        0
# 4    ..\Data\Italian\f1\dis-f1-d2.wav  disgust           1        0
# ..                                ...      ...         ...      ...
# 583  ..\Data\Italian\m3\tri-m3-n1.wav  sadness           6        0
# 584  ..\Data\Italian\m3\tri-m3-n2.wav  sadness           6        0
# 585  ..\Data\Italian\m3\tri-m3-n3.wav  sadness           6        0
# 586  ..\Data\Italian\m3\tri-m3-n4.wav  sadness           6        0
# 587  ..\Data\Italian\m3\tri-m3-n5.wav  sadness           6        0
#
#      F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                            38.041195
# 1                            40.034466
# 2                            40.346146
# 3                            40.030760
# 4                            34.739250
# ..                                 ...
# 583                          23.583319
# 584                          24.619745
# 585                          22.285524
# 586                          24.609354
# 587                          25.380743
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.062761
# 1                                  0.079689
# 2                                  0.062860
# 3                                  0.142646
# 4                                  0.244674
# ..                                      ...
# 583                                0.100119
# 584                                0.289437
# 585                                0.068445
# 586                                0.379780
# 587                                0.444126
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                     36.693428
# 1                                     37.188023
# 2                                     37.921173
# 3                                     35.758670
# 4                                     31.769650
# ..                                          ...
# 583                                   22.266697
# 584                                   21.803062
# 585                                   21.515762
# 586                                   20.980080
# 587                                   20.821350
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                     38.990890
# 1                                     40.978490
# 2                                     41.041718
# 3                                     42.093567
# 4                                     37.416992
# ..                                          ...
# 583                                   22.899254
# 584                                   23.222479
# 585                                   22.025902
# 586                                   21.951263
# 587                                   21.613827
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                     39.750580
# 1                                     43.000435
# 2                                     42.420360
# 3                                     44.378150
# 4                                     39.738840
# ..                                          ...
# 583                                   25.167519
# 584                                   25.559631
# 585                                   22.980757
# 586                                   23.954580
# 587                                   23.264252
#
#      F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  ...  slopeUV0-500_sma3nz_amean  \
# 0                                    3.057152  ...                  -0.054321
# 1                                    5.812412  ...                  -0.041974
# 2                                    4.499187  ...                  -0.042082
# 3                                    8.619480  ...                  -0.031066
# 4                                    7.969189  ...                  -0.054390
# ..                                        ...  ...                        ...
# 583                                  2.900822  ...                  -0.014884
# 584                                  3.756569  ...                  -0.024741
# 585                                  1.464994  ...                  -0.036319
# 586                                  2.974501  ...                  -0.028809
# 587                                  2.442902  ...                  -0.026875
#
#      slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 0                       -0.002343                     0.195009
# 1                        0.000791                     0.143104
# 2                        0.000804                     0.195658
# 3                       -0.002760                     0.264424
# 4                       -0.005514                     0.162280
# ..                            ...                          ...
# 583                     -0.002672                     0.073181
# 584                      0.002552                     0.087258
# 585                     -0.001369                     0.057797
# 586                      0.000764                     0.047844
# 587                     -0.004511                     0.037394
#
#      loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0               2.816901              1.792115                    0.186000
# 1               4.577465              2.150538                    0.215000
# 2               3.797468              2.155173                    0.244000
# 3               3.535354              3.108808                    0.108333
# 4               2.888087              2.941176                    0.132500
# ..                   ...                   ...                         ...
# 583             5.376344              3.314917                    0.145000
# 584             4.193549              2.622951                    0.201250
# 585             4.471545              2.904564                    0.135714
# 586             2.862986              2.272727                    0.148182
# 587             2.985075              2.636535                    0.149286
#
#      StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                        0.057480                   0.291667
# 1                        0.112953                   0.195714
# 2                        0.233461                   0.242500
# 3                        0.052731                   0.158571
# 4                        0.060570                   0.185000
# ..                            ...                        ...
# 583                      0.072284                   0.115714
# 584                      0.256488                   0.141111
# 585                      0.130915                   0.185714
# 586                      0.224533                   0.270000
# 587                      0.113419                   0.208571
#
#      StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# 0                       0.316934                -20.434135
# 1                       0.241238                -22.372519
# 2                       0.151554                -21.750406
# 3                       0.181220                -24.157581
# 4                       0.200250                -25.894457
# ..                           ...                       ...
# 583                     0.054210                -42.053710
# 584                     0.123868                -41.644410
# 585                     0.163258                -45.182545
# 586                     0.289796                -45.173462
# 587                     0.239996                -46.796707
#
# [588 rows x 92 columns]

# %%
df["speaker_id"].unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# ### Data Preprocessing
# * we have a small dataset with unbalanced data. we need to be careful about overfitting. We want to have balanced data, so we use SMOTE to oversample the minority class (this usually works well for smaller datasets)
# * we need GroupKfold crossvalidation, as we do not want to have speakers from the training in the test dataset
#
# => we do this all together in the pipepline

# %%
# check classes
df['valence'].value_counts()
# Out:
# valence
# 0    336
# 1    252
# Name: count, dtype: int64

# %% [markdown]
# ### Model Training

# %%
X = df.drop(["emotion", "speaker_id", "filename", "valence"], axis=1)  # Features
y = df["valence"]  # Labels
groups = df["speaker_id"]  

# Initialize GroupKFold with 5 folds 
gkf = GroupKFold(n_splits=5)

# For the English dataset we initialize with 4 folds (since n = 4 < 5)
#gkf = GroupKFold(n_splits=4)

# Initialize models
svm_model = SVC(probability=True, random_state=42)
logreg_model = LogisticRegression(max_iter=1000, random_state=42)
xgb_model = XGBClassifier(random_state=42)
randomForest_model = RandomForestClassifier(random_state=42)

# Create pipelines
svm_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("smote", SMOTE(random_state=42)),
    ("classifier", svm_model)
])

logreg_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("smote", SMOTE(random_state=42)),
    ("classifier", logreg_model)
])

xgb_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("smote", SMOTE(random_state=42)),
    ("classifier", xgb_model)
])

randomForest_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("smote", SMOTE(random_state=42)),
    ("classifier", randomForest_model)
])

# %% [markdown]
# ### Evaluation
# in the paper they used unweighted average recall rate (UAR) which gives equal weight to each class, making it good for imbalanced datasets. UAR is the same as balanced accuracy.
# we choose to check also other metrics, which are good for imbalanced date, like f1 score.

# %%
scoring_metrics = ["accuracy", "balanced_accuracy", "f1_weighted", "roc_auc_ovr", "precision_weighted", "recall_weighted"]
results = []

# Evaluate pipelines using different metrics
for metric in scoring_metrics:
    svm_scores = cross_val_score(svm_pipeline, X, y, groups=groups, cv=gkf, scoring=metric)
    logreg_scores = cross_val_score(logreg_pipeline, X, y, groups=groups, cv=gkf, scoring=metric)
    xgb_scores = cross_val_score(xgb_pipeline, X, y, groups=groups, cv=gkf, scoring=metric)
    randomForest_scores = cross_val_score(randomForest_pipeline, X, y, groups=groups, cv=gkf, scoring=metric)
    
    # Store results
    results.append(["SVM", metric, svm_scores.mean()])
    results.append(["Logistic Regression", metric, logreg_scores.mean()])
    results.append(["Random Forest", metric, randomForest_scores.mean()])
    results.append(["XGBoost", metric, xgb_scores.mean()])


results_df = pd.DataFrame(results, columns=["Model", "Metric", "Score"])
results_df
# Out:
#                   Model              Metric     Score
# 0                   SVM            accuracy  0.613265
# 1   Logistic Regression            accuracy  0.632653
# 2         Random Forest            accuracy  0.598980
# 3               XGBoost            accuracy  0.622449
# 4                   SVM   balanced_accuracy  0.577083
# 5   Logistic Regression   balanced_accuracy  0.624107
# 6         Random Forest   balanced_accuracy  0.567262
# 7               XGBoost   balanced_accuracy  0.592560
# 8                   SVM         f1_weighted  0.564406
# 9   Logistic Regression         f1_weighted  0.612025
# 10        Random Forest         f1_weighted  0.560570
# 11              XGBoost         f1_weighted  0.595371
# 12                  SVM         roc_auc_ovr  0.653444
# 13  Logistic Regression         roc_auc_ovr  0.663861
# 14        Random Forest         roc_auc_ovr  0.593091
# 15              XGBoost         roc_auc_ovr  0.635927
# 16                  SVM  precision_weighted  0.623488
# 17  Logistic Regression  precision_weighted  0.659273
# 18        Random Forest  precision_weighted  0.592141
# 19              XGBoost  precision_weighted  0.624364
# 20                  SVM     recall_weighted  0.613265
# 21  Logistic Regression     recall_weighted  0.632653
# 22        Random Forest     recall_weighted  0.598980
# 23              XGBoost     recall_weighted  0.622449

# %%
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")
sns.set_palette("viridis")
sns.barplot(data=results_df, x="Metric", y="Score", hue="Model")

# Add labels and title
plt.title('Model Performance on Different Metrics', fontsize=16)
plt.xlabel('Model', fontsize=12)
plt.ylabel('Score', fontsize=12)

plt.legend(title="Metric", bbox_to_anchor=(1.05, 0.5), loc='center left')
# Display the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
