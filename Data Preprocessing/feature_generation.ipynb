# %% [markdown]
# ## Feature Generation
# In this file, we generate features for all four languages.
#
# Input: DataFrame with file paths.
#
# Output: DataFrame with features for all four languages.

# %% [markdown]
# ### Introduction to geMAPS (Geneva Minimalistic Acoustic Parameter Set)
#
# - geMAPS is used as a minimalistic parameter set for acoustic analysis, including features most related to emotions.
# - It consists of 88 features related to energy, frequency, cepstral, spectral, and dynamic information.
# - We used all features, as done in the paper Latif et al.
# - We used the OpenSMILE toolkit for feature extraction.
# - We used the latest version, GeMAPSv02.
#
# The following paper introduces geMAPS and provides detailed background information on the individual features and their meaning:
# https://arxiv.org/pdf/1812.10411
#
# Eyben, F., Scherer, K. R., Schuller, B. W., Sundberg, J., André, E., Busso, C., Devillers, L. Y., Epps, J., Laukka, P., Narayanan, S. S., et al. (2016).
# The Geneva minimalistic acoustic parameter set (GeMAPS) for voice research and affective computing.
# IEEE Transactions on Affective Computing, 7(2), 190–202.

# %%
# dependecies
import opensmile
import pandas as pd

# %%
# data
df_german = pd.read_csv(r'..\Data\German\data_path_german.csv')
df_urdu = pd.read_csv(r'..\Data\Urdu\data_path_urdu.csv')
df_english = pd.read_csv(r'..\Data\English\data_path_english.csv')
df_italian = pd.read_csv(r'..\Data\Italian\data_path_italian.csv')

# %%
def extract_features(df, column="filename"):
    # openSMILE initialization (eGeMAPS configuration)
    smile = opensmile.Smile(
        feature_set=opensmile.FeatureSet.eGeMAPSv02,
        feature_level=opensmile.FeatureLevel.Functionals,
    )

    # Feature extraction
    features = [smile.process_file(path) for path in df[column]]

    # Combine features with the dataframe
    features_df = pd.concat(features).reset_index(drop=True)
    return pd.concat([df, features_df], axis=1)

# %%
df_features_german = extract_features(df_german)

# %%
df_features_urdu = extract_features(df_urdu)

# %%
df_features_english = extract_features(df_english)

# %%
df_features_italian = extract_features(df_italian)

# %%
df_features_german.head()
# Out:
#                          filename    emotion  speaker_id  valence  \
# 0  ..\Data\German\wav\03a01Fa.wav  happiness           3        1
# 1  ..\Data\German\wav\03a01Nc.wav    neutral           3        1
# 2  ..\Data\German\wav\03a01Wa.wav      anger           3        0
# 3  ..\Data\German\wav\03a02Fc.wav  happiness           3        1
# 4  ..\Data\German\wav\03a02Nc.wav    neutral           3        1
#
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          31.188166                                0.152560
# 1                          25.022938                                0.148540
# 2                          34.292320                                0.102067
# 3                          37.576572                                0.108607
# 4                          25.040190                                0.116655
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   27.766502
# 1                                   20.637066
# 2                                   30.504089
# 3                                   34.083504
# 4                                   21.225212
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   31.412098
# 1                                   25.118477
# 2                                   33.584766
# 3                                   37.371193
# 4                                   26.198669
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                   36.340343
# 1                                   28.660353
# 2                                   37.343616
# 3                                   41.233379
# 4                                   27.725224
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  ...  slopeUV0-500_sma3nz_amean  \
# 0                                  8.573841  ...                  -0.012351
# 1                                  8.023287  ...                  -0.020058
# 2                                  6.839527  ...                   0.014669
# 3                                  7.149876  ...                  -0.007576
# 4                                  6.500011  ...                  -0.035085
#
#    slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 0                      0.010897                     0.218922
# 1                      0.007849                     0.450747
# 2                      0.012394                     0.388366
# 3                      0.015585                     0.243682
# 4                      0.005547                     0.444158
#
#    loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0             4.255319              3.278689                    0.156667
# 1             6.250000              3.870968                    0.101667
# 2             4.838710              3.314917                    0.150000
# 3             4.522613              2.577320                    0.246000
# 4             6.338028              3.649635                    0.148000
#
#    StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                      0.084591                   0.108571
# 1                      0.055202                   0.115714
# 2                      0.073030                   0.111429
# 3                      0.210960                   0.100000
# 4                      0.130138                   0.086667
#
#    StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# 0                     0.036422                -21.647932
# 1                     0.049816                -18.010019
# 2                     0.060339                -17.855310
# 3                     0.042032                -18.062223
# 4                     0.026247                -16.109831
#
# [5 rows x 92 columns]

# %%
df_features_german.describe()
# Out:
#        speaker_id     valence  F0semitoneFrom27.5Hz_sma3nz_amean  \
# count  535.000000  535.000000                         535.000000
# mean    11.472897    0.280374                          33.367603
# std      3.702251    0.449602                           6.191615
# min      3.000000    0.000000                          20.147655
# 25%      9.000000    0.000000                          29.264296
# 50%     12.000000    0.000000                          33.732170
# 75%     14.000000    1.000000                          38.042564
# max     16.000000    1.000000                          45.786362
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# count                              535.000000
# mean                                 0.120374
# std                                  0.057875
# min                                  0.019742
# 25%                                  0.084569
# 50%                                  0.111077
# 75%                                  0.144153
# max                                  0.463821
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# count                                  535.000000
# mean                                    30.512604
# std                                      6.209119
# min                                     17.220638
# 25%                                     27.018799
# 50%                                     30.501961
# 75%                                     35.212271
# max                                     42.890316
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# count                                  535.000000
# mean                                    33.475433
# std                                      6.458098
# min                                     18.841173
# 25%                                     29.690395
# 50%                                     33.853790
# 75%                                     38.116758
# max                                     46.653229
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# count                                  535.000000
# mean                                    36.076904
# std                                      6.631866
# min                                     21.158241
# 25%                                     31.565550
# 50%                                     36.618462
# 75%                                     41.019220
# max                                     49.106670
#
#        F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# count                                535.000000
# mean                                   5.564307
# std                                    2.441472
# min                                    0.994576
# 25%                                    3.833981
# 50%                                    5.282652
# 75%                                    6.941219
# max                                   14.623859
#
#        F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# count                                   535.000000
# mean                                    116.832565
# std                                     177.440536
# min                                     -17.176445
# 25%                                      42.242756
# 50%                                      73.463837
# 75%                                     120.763279
# max                                    2099.327393
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# count                                     535.000000  ...
# mean                                      112.051010  ...
# std                                       208.596298  ...
# min                                         0.000000  ...
# 25%                                        23.909872  ...
# 50%                                        59.961407  ...
# 75%                                       119.356491  ...
# max                                      2057.664062  ...
#
#        slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# count                 535.000000                    535.000000
# mean                   -0.013980                      0.009047
# std                     0.020137                      0.005618
# min                    -0.062705                     -0.007013
# 25%                    -0.027801                      0.005360
# 50%                    -0.014744                      0.008929
# 75%                     0.001656                      0.012791
# max                     0.034950                      0.025862
#
#        spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# count                   535.000000           535.000000            535.000000
# mean                      0.393371             4.884980              3.353735
# std                       0.164857             0.932381              0.865623
# min                       0.068661             2.651515              1.388889
# 25%                       0.273016             4.187063              2.684280
# 50%                       0.378999             4.884319              3.272727
# 75%                       0.493557             5.555556              3.948727
# max                       1.203116             7.792208              6.250000
#
#        MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# count                  535.000000                    535.000000
# mean                     0.179354                      0.130237
# std                      0.070406                      0.070510
# min                      0.042000                      0.010897
# 25%                      0.128377                      0.080081
# 50%                      0.165000                      0.116940
# 75%                      0.217333                      0.168090
# max                      0.525000                      0.536050
#
#        MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# count                 535.000000                   535.000000
# mean                    0.111292                     0.079168
# std                     0.055454                     0.078171
# min                     0.036250                     0.008292
# 25%                     0.075778                     0.036636
# 50%                     0.095833                     0.053144
# 75%                     0.126410                     0.085929
# max                     0.453846                     0.544052
#
#        equivalentSoundLevel_dBp
# count                535.000000
# mean                 -18.141733
# std                    2.296502
# min                  -26.144777
# 25%                  -19.750538
# 50%                  -18.155230
# 75%                  -16.637753
# max                  -11.847078
#
# [8 rows x 90 columns]

# %%
df_features_urdu.head()
# Out:
#                               filename emotion  speaker_id  valence  \
# 0  ..\Data\Urdu\Angry\SM1_F10_A010.wav   Angry          12        0
# 1  ..\Data\Urdu\Angry\SM1_F11_A011.wav   Angry          12        0
# 2  ..\Data\Urdu\Angry\SM1_F12_A012.wav   Angry          12        0
# 3  ..\Data\Urdu\Angry\SM1_F13_A013.wav   Angry          12        0
# 4  ..\Data\Urdu\Angry\SM1_F14_A014.wav   Angry          12        0
#
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          37.416851                                0.162711
# 1                          39.290840                                0.048453
# 2                          36.559757                                0.159693
# 3                          39.653111                                0.099355
# 4                          40.303036                                0.095656
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   36.100449
# 1                                   38.296627
# 2                                   31.332470
# 3                                   38.884323
# 4                                   39.875011
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   39.646458
# 1                                   39.442600
# 2                                   39.228329
# 3                                   40.339897
# 4                                   40.965897
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                   41.276707
# 1                                   40.628967
# 2                                   40.891193
# 3                                   41.908745
# 4                                   42.031673
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  ...  slopeUV0-500_sma3nz_amean  \
# 0                                  5.176258  ...                  -0.020775
# 1                                  2.332340  ...                  -0.053453
# 2                                  9.558723  ...                  -0.063400
# 3                                  3.024422  ...                  -0.051385
# 4                                  2.156662  ...                  -0.058390
#
#    slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 0                     -0.025433                     0.560624
# 1                     -0.029727                     1.589942
# 2                     -0.029255                     0.695361
# 3                     -0.025643                     0.648632
# 4                     -0.023010                     0.731930
#
#    loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0             4.347826              2.389079                    0.325714
# 1             7.035176              1.554404                    0.613333
# 2             5.016722              2.730376                    0.278750
# 3             4.522613              2.072539                    0.387500
# 4             4.682274              3.071672                    0.252222
#
#    StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                      0.353548                   0.163333
# 1                      0.318573                   0.030000
# 2                      0.293106                   0.106000
# 3                      0.192273                   0.075000
# 4                      0.218316                   0.056250
#
#    StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# 0                     0.168589                -21.443512
# 1                     0.000000                -18.693861
# 2                     0.124354                -19.787762
# 3                     0.048218                -19.527483
# 4                     0.077611                -19.405691
#
# [5 rows x 92 columns]

# %%
df_features_urdu.describe()
# Out:
#        speaker_id     valence  F0semitoneFrom27.5Hz_sma3nz_amean  \
# count  400.000000  400.000000                         400.000000
# mean    19.290000    0.500000                          31.336248
# std     10.347152    0.500626                           6.458869
# min      1.000000    0.000000                          16.103161
# 25%     13.000000    0.000000                          25.909101
# 50%     16.000000    0.500000                          30.173744
# 75%     31.000000    1.000000                          36.980701
# max     38.000000    1.000000                          47.869175
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# count                              400.000000
# mean                                 0.180478
# std                                  0.086679
# min                                  0.034696
# 25%                                  0.115079
# 50%                                  0.167304
# 75%                                  0.229270
# max                                  0.562860
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# count                                  400.000000
# mean                                    27.845217
# std                                      7.631450
# min                                     13.180742
# 25%                                     21.412821
# 50%                                     26.713662
# 75%                                     35.051414
# max                                     44.254688
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# count                                  400.000000
# mean                                    31.966284
# std                                      7.251650
# min                                     15.542145
# 25%                                     26.067571
# 50%                                     31.598275
# 75%                                     38.489667
# max                                     49.352264
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# count                                  400.000000
# mean                                    35.231171
# std                                      7.143315
# min                                     18.273960
# 25%                                     29.598001
# 50%                                     35.244669
# 75%                                     40.857296
# max                                     56.120388
#
#        F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# count                                400.000000
# mean                                   7.385953
# std                                    5.534096
# min                                    1.010445
# 25%                                    3.571141
# 50%                                    5.512575
# 75%                                    9.144600
# max                                   38.984764
#
#        F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# count                                   400.000000
# mean                                    189.593445
# std                                     136.639847
# min                                      13.644010
# 25%                                     100.439697
# 50%                                     151.904167
# 75%                                     231.306713
# max                                    1145.211060
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# count                                     400.000000  ...
# mean                                      188.173904  ...
# std                                       200.004868  ...
# min                                         0.000000  ...
# 25%                                        70.898956  ...
# 50%                                       126.761673  ...
# 75%                                       205.170452  ...
# max                                      1372.831055  ...
#
#        slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# count                 400.000000                    400.000000
# mean                   -0.016755                     -0.014217
# std                     0.053758                      0.009044
# min                    -0.123982                     -0.041677
# 25%                    -0.062565                     -0.019920
# 50%                    -0.022157                     -0.014039
# 75%                     0.017180                     -0.009319
# max                     0.128315                      0.008411
#
#        spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# count                   400.000000           400.000000            400.000000
# mean                      0.630703             4.589922              2.212048
# std                       0.615389             1.260188              0.931747
# min                       0.000000             0.334448              0.341297
# 25%                       0.218711             3.678930              1.554404
# 50%                       0.440754             4.522613              2.072539
# 75%                       0.813291             5.527638              2.730376
# max                       4.029183             7.537688              5.154639
#
#        MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# count                  400.000000                    400.000000
# mean                     0.472308                      0.323471
# std                      0.336814                      0.204619
# min                      0.077857                      0.000000
# 25%                      0.269375                      0.182182
# 50%                      0.375857                      0.283668
# 75%                      0.583333                      0.412931
# max                      2.920000                      1.305000
#
#        MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# count                 400.000000                   400.000000
# mean                    0.093616                     0.062397
# std                     0.121013                     0.081287
# min                     0.000000                     0.000000
# 25%                     0.043333                     0.009857
# 50%                     0.071111                     0.039081
# 75%                     0.106786                     0.079054
# max                     1.910000                     0.655303
#
#        equivalentSoundLevel_dBp
# count                400.000000
# mean                 -21.094116
# std                    6.840863
# min                  -41.870106
# 25%                  -25.036286
# 50%                  -19.646758
# 75%                  -16.115501
# max                   -7.979055
#
# [8 rows x 90 columns]

# %%
df_features_english.head()
# Out:
#                      filename emotion  speaker_id  valence  \
# 0  ..\Data\English\DC\a01.wav   anger           2        0
# 1  ..\Data\English\DC\a02.wav   anger           2        0
# 2  ..\Data\English\DC\a03.wav   anger           2        0
# 3  ..\Data\English\DC\a04.wav   anger           2        0
# 4  ..\Data\English\DC\a05.wav   anger           2        0
#
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          32.288380                                0.253543
# 1                          28.624495                                0.083322
# 2                          32.756123                                0.073900
# 3                          30.764030                                0.126925
# 4                          32.762295                                0.264996
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   28.019905
# 1                                   27.068924
# 2                                   30.584631
# 3                                   28.082649
# 4                                   28.170233
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   31.009491
# 1                                   28.368698
# 2                                   33.153530
# 3                                   31.094275
# 4                                   30.551094
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                   34.035744
# 1                                   29.564381
# 2                                   34.469784
# 3                                   33.430504
# 4                                   34.771942
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  ...  slopeUV0-500_sma3nz_amean  \
# 0                                  6.015839  ...                  -0.130033
# 1                                  2.495457  ...                  -0.127977
# 2                                  3.885153  ...                  -0.128269
# 3                                  5.347855  ...                  -0.113702
# 4                                  6.601709  ...                  -0.104462
#
#    slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 0                     -0.008058                     0.175102
# 1                     -0.008800                     0.123429
# 2                     -0.007824                     0.087312
# 3                     -0.010014                     0.088040
# 4                     -0.010390                     0.082960
#
#    loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0             3.581267              2.234637                    0.296250
# 1             3.508772              0.890208                    0.666667
# 2             2.427185              0.995025                    0.495000
# 3             3.690037              1.127820                    0.553333
# 4             3.691275              1.706485                    0.374000
#
#    StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                      0.255389                   0.247500
# 1                      0.507631                   0.325000
# 2                      0.265000                   0.323333
# 3                      0.402851                   0.232500
# 4                      0.653226                   0.188000
#
#    StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# 0                     0.217529                -15.691360
# 1                     0.268375                -15.941064
# 2                     0.197540                -13.958084
# 3                     0.181435                -13.020000
# 4                     0.185515                -13.182361
#
# [5 rows x 92 columns]

# %%
df_features_english.describe()
# Out:
#        speaker_id     valence  F0semitoneFrom27.5Hz_sma3nz_amean  \
# count    480.0000  480.000000                         480.000000
# mean       3.5000    0.500000                          30.256489
# std        1.1192    0.500522                           4.105783
# min        2.0000    0.000000                          23.635603
# 25%        2.7500    0.000000                          26.609159
# 50%        3.5000    0.500000                          29.493928
# 75%        4.2500    1.000000                          33.432803
# max        5.0000    1.000000                          40.492531
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# count                              480.000000
# mean                                 0.172518
# std                                  0.059402
# min                                  0.025336
# 25%                                  0.125357
# 50%                                  0.171257
# 75%                                  0.214835
# max                                  0.363688
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# count                                  480.000000
# mean                                    26.780107
# std                                      3.971195
# min                                     19.291630
# 25%                                     23.696812
# 50%                                     25.547376
# 75%                                     29.300300
# max                                     38.866936
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# count                                  480.000000
# mean                                    30.204046
# std                                      4.452664
# min                                     22.908981
# 25%                                     26.286766
# 50%                                     29.218877
# 75%                                     33.514755
# max                                     43.058502
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# count                                  480.000000
# mean                                    33.262714
# std                                      4.707262
# min                                     25.194229
# 25%                                     29.226478
# 50%                                     32.633621
# 75%                                     36.756875
# max                                     48.740047
#
#        F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# count                                480.000000
# mean                                   6.482605
# std                                    2.931754
# min                                    1.381569
# 25%                                    4.604247
# 50%                                    5.954197
# 75%                                    7.864131
# max                                   26.323328
#
#        F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# count                                   480.000000
# mean                                    303.784515
# std                                     267.066315
# min                                      -0.314711
# 25%                                     128.488979
# 50%                                     218.228485
# 75%                                     385.746376
# max                                    1740.932129
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# count                                     480.000000  ...
# mean                                      360.150452  ...
# std                                       370.752838  ...
# min                                         4.638756  ...
# 25%                                       113.021105  ...
# 50%                                       219.787659  ...
# 75%                                       456.553902  ...
# max                                      2042.238403  ...
#
#        slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# count                 480.000000                    480.000000
# mean                   -0.107896                     -0.010159
# std                     0.019555                      0.002789
# min                    -0.137654                     -0.018645
# 25%                    -0.125602                     -0.011590
# 50%                    -0.113390                     -0.009970
# 75%                    -0.091891                     -0.008473
# max                    -0.062683                     -0.002343
#
#        spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# count                   480.000000           480.000000            480.000000
# mean                      0.120050             3.214889              1.939821
# std                       0.105587             0.608367              0.616214
# min                       0.003892             1.302932              0.431035
# 25%                       0.028586             2.804872              1.522360
# 50%                       0.106166             3.253621              1.914139
# 75%                       0.161364             3.658537              2.361628
# max                       0.738632             4.645477              3.846154
#
#        MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# count                  480.000000                    480.000000
# mean                     0.336434                      0.231548
# std                      0.164726                      0.128509
# min                      0.127500                      0.000000
# 25%                      0.235750                      0.144586
# 50%                      0.292159                      0.206165
# 75%                      0.390278                      0.272572
# max                      1.490000                      0.829348
#
#        MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# count                 480.000000                   480.000000
# mean                    0.206984                     0.194025
# std                     0.077061                     0.064718
# min                     0.062500                     0.000000
# 25%                     0.154000                     0.150665
# 50%                     0.188000                     0.188445
# 75%                     0.242500                     0.229500
# max                     0.500000                     0.441802
#
#        equivalentSoundLevel_dBp
# count                480.000000
# mean                 -23.038940
# std                   10.581980
# min                  -46.165237
# 25%                  -27.467969
# 50%                  -19.969756
# 75%                  -14.987313
# max                   -7.375777
#
# [8 rows x 90 columns]

# %%
df_features_italian.head()
# Out:
#                            filename  emotion  speaker_id  valence  \
# 0  ..\Data\Italian\f1\dis-f1-b1.wav  disgust           1        0
# 1  ..\Data\Italian\f1\dis-f1-b2.wav  disgust           1        0
# 2  ..\Data\Italian\f1\dis-f1-b3.wav  disgust           1        0
# 3  ..\Data\Italian\f1\dis-f1-d1.wav  disgust           1        0
# 4  ..\Data\Italian\f1\dis-f1-d2.wav  disgust           1        0
#
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          38.041195                                0.062761
# 1                          40.034466                                0.079689
# 2                          40.346146                                0.062860
# 3                          40.030762                                0.142646
# 4                          34.739250                                0.244674
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   36.693428
# 1                                   37.188023
# 2                                   37.921173
# 3                                   35.758671
# 4                                   31.769650
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   38.990891
# 1                                   40.978489
# 2                                   41.041718
# 3                                   42.093567
# 4                                   37.416992
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                   39.750580
# 1                                   43.000435
# 2                                   42.420361
# 3                                   44.378151
# 4                                   39.738838
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  ...  slopeUV0-500_sma3nz_amean  \
# 0                                  3.057152  ...                  -0.054321
# 1                                  5.812412  ...                  -0.041974
# 2                                  4.499187  ...                  -0.042082
# 3                                  8.619480  ...                  -0.031066
# 4                                  7.969189  ...                  -0.054390
#
#    slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 0                     -0.002343                     0.195009
# 1                      0.000791                     0.143104
# 2                      0.000804                     0.195658
# 3                     -0.002760                     0.264424
# 4                     -0.005514                     0.162280
#
#    loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0             2.816901              1.792115                    0.186000
# 1             4.577465              2.150538                    0.215000
# 2             3.797468              2.155173                    0.244000
# 3             3.535354              3.108808                    0.108333
# 4             2.888087              2.941176                    0.132500
#
#    StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                      0.057480                   0.291667
# 1                      0.112953                   0.195714
# 2                      0.233461                   0.242500
# 3                      0.052731                   0.158571
# 4                      0.060570                   0.185000
#
#    StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# 0                     0.316934                -20.434135
# 1                     0.241238                -22.372519
# 2                     0.151554                -21.750406
# 3                     0.181220                -24.157581
# 4                     0.200250                -25.894457
#
# [5 rows x 92 columns]

# %%
df_features_italian.describe()
# Out:
#        speaker_id     valence  F0semitoneFrom27.5Hz_sma3nz_amean  \
# count  588.000000  588.000000                         588.000000
# mean     3.500000    0.428571                          32.823833
# std      1.709279    0.495293                           6.615926
# min      1.000000    0.000000                          18.977774
# 25%      2.000000    0.000000                          27.499894
# 50%      3.500000    0.000000                          33.334251
# 75%      5.000000    1.000000                          37.886450
# max      6.000000    1.000000                          48.275318
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# count                              588.000000
# mean                                 0.149914
# std                                  0.087972
# min                                  0.025086
# 25%                                  0.085417
# 50%                                  0.124595
# 75%                                  0.190486
# max                                  0.541119
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# count                                  588.000000
# mean                                    29.698973
# std                                      6.945529
# min                                     14.541317
# 25%                                     23.262286
# 50%                                     30.251659
# 75%                                     35.693129
# max                                     46.561592
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# count                                  588.000000
# mean                                    32.858936
# std                                      7.092430
# min                                     16.669413
# 25%                                     26.796164
# 50%                                     34.013554
# 75%                                     38.178176
# max                                     48.956268
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# count                                  588.000000
# mean                                    35.491791
# std                                      7.198244
# min                                     20.769951
# 25%                                     30.217428
# 50%                                     36.764938
# 75%                                     40.630622
# max                                     54.339100
#
#        F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# count                                588.000000
# mean                                   5.792822
# std                                    3.513937
# min                                    1.213686
# 25%                                    3.467685
# 50%                                    4.812626
# 75%                                    6.889064
# max                                   32.431450
#
#        F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# count                                   588.000000
# mean                                    191.265701
# std                                     206.508545
# min                                     -84.257759
# 25%                                      75.745684
# 50%                                     125.463875
# 75%                                     221.618687
# max                                    1392.867065
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# count                                     588.000000  ...
# mean                                      196.998199  ...
# std                                       281.652283  ...
# min                                         0.000000  ...
# 25%                                        58.174125  ...
# 50%                                       110.067509  ...
# 75%                                       195.594597  ...
# max                                      1816.597046  ...
#
#        slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# count                 588.000000                    588.000000
# mean                   -0.006676                      0.001051
# std                     0.047366                      0.006463
# min                    -0.077706                     -0.014120
# 25%                    -0.040329                     -0.002981
# 50%                    -0.017467                     -0.000368
# 75%                     0.005218                      0.003488
# max                     0.145348                      0.023100
#
#        spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# count                   588.000000           588.000000            588.000000
# mean                      0.300891             4.264936              2.798721
# std                       0.315039             0.951171              0.733288
# min                       0.009889             1.359084              0.662252
# 25%                       0.072783             3.614213              2.294925
# 50%                       0.154169             4.250802              2.803888
# 75%                       0.454017             4.848485              3.262646
# max                       1.540660             7.407407              5.737705
#
#        MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# count                  588.000000                    588.000000
# mean                     0.201802                      0.143255
# std                      0.102293                      0.081356
# min                      0.035000                      0.000000
# 25%                      0.140000                      0.090996
# 50%                      0.183333                      0.127440
# 75%                      0.238000                      0.177903
# max                      1.020000                      0.655000
#
#        MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# count                 588.000000                   588.000000
# mean                    0.156331                     0.149395
# std                     0.078643                     0.100291
# min                     0.042500                     0.011990
# 25%                     0.107240                     0.078228
# 50%                     0.143667                     0.129015
# 75%                     0.188393                     0.192422
# max                     0.926429                     0.956101
#
#        equivalentSoundLevel_dBp
# count                588.000000
# mean                 -29.704155
# std                    8.837218
# min                  -51.442650
# 25%                  -36.708788
# 50%                  -29.183656
# 75%                  -20.916226
# max                  -16.133909
#
# [8 rows x 90 columns]

# %%
# save features
df_features_german.to_csv("../Data/German/features_german.csv",index=False)
df_features_urdu.to_csv("../Data/Urdu/features_urdu.csv",index=False)
df_features_english.to_csv("../Data/English/features_english.csv",index=False)
df_features_italian.to_csv("../Data/Italian/features_italian.csv",index=False)
